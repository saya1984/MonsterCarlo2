# %%
# %pylab inline
import pickle

results = 0
with open("mcts_model_0.pickle", "rb") as f:
    results = pickle.load(f)
a = 0
for result in results:
    print(a)
    a = a+1
    print(result["score"])
    print(result["random_seed"])
    print(result["path"])
    print(result["blocks"])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 0
# 15
# 329829
# [{'a': 0, 'c': 2}, {'a': 2, 'c': 3}]
# (6,3) (6,1)
# (6,2) (3,2) (9,1)  | (3,1) (2,2) (1,3)  |
#  |  |  |  |  |  |
#
# 1
# 25
# 332515
# [{'a': 1, 'c': 3}, {'a': 1, 'c': 3}, {'a': 0, 'c': 2}, {'a': 2, 'c': 3}]
# (3,1) (6,3) (3,1)
# (2,1) (3,1) (3,3)  | (6,1) (6,2) (6,3)  | (3,2) (3,3)  |
# (3,3) (3,2) (1,2)  | (3,1) (2,2) (2,2)  | (6,2) (3,3) (3,2)  | (3,2) (3,2) (2,1)  | (4,3) (4,1)  | (3,1) (6,2)  | (6,2) (4,2)  | (9,3) (3,2) (6,1)  |
# (6,1) (3,2) (6,1)  | (2,3) (6,2)  | (6,2) (4,3)  | (2,1) (1,3)  | (6,3) (2,3)  | (4,2) (2,3)  | (2,2) (2,3)  | (6,2) (6,1) (3,2)  | (2,1) (6,2) (6,1)  | (6,3) (2,2)  | (2,1) (2,3) (6,3)  | (2,3) (2,1) (1,3)  | (3,1) (6,2) (9,1)  | (2,2) (1,3)  | (2,2) (1,3)  | (6,3) (4,3)  | (2,1) (6,1) (2,1)  | (2,1) (4,3)  | (9,3) (3,3) (6,1)  | (2,3) (4,1) (4,2)  | (1,2) (3,3)  |
# ...
